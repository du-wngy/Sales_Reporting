# %% [markdown]
# ## Task 1: Import packages and Load data

# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt

# file_name = input('Please key in the file name: ')
# df = pd.read_csv(file_name)
# df

# %%
path = "D:/thingsBasic/pyBasic/sale_reporting/data/"
df = pd.read_csv(path + "sales2019_1.csv")
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# ## Task 2: Clean and Preprocess data

# %% [markdown]
# ### Taskl 2.1: Merge 12 - months

# %%
frames = []
all_length = []
for file in os.listdir(path):
# Duyệt từng phần tử và tạo file path cụ thể
    if file.endswith('.csv'):
        file_path = path + file
        df_01 = pd.read_csv(file_path)
        frames.append(df_01)
        # Thêm từng df vào list frames
        result = pd.concat(frames)
        lengt_1month = len(df_01.index)
        all_length.append(lengt_1month)
result  

# Xuất ra 1 file tổng
df = result
df.to_csv('annual_sale2019.csv', index = False)

# %%
print(sum(all_length))
# Out:
# 186850

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# ### Task 2.2: Add 'Month' column

# %%
df['Month'] = ''
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
df['Month'] = df['Order Date'].str[0:2]

# %%
print(set(df['Month']))
# Xuất hiện giá trị nhiễu
# Out:
# {'10', '07', '09', '04', '01', '02', '05', 'Or', '12', '11', '03', '08', nan, '06'}

# %% [markdown]
# ### Task 2.3: Get rid of "NaN" and "Or" value

# %%
df = df.dropna(how='all')
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
df[df['Month'] == 'Or']
# Kiểm tra giá trị or là cái gì
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 10000  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10387  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11399  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11468  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11574  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 1073   Purchase Address    Or
# 1102   Purchase Address    Or
# 1194   Purchase Address    Or
# 1897   Purchase Address    Or
# ...

# %%
df = df[df['Month'] != 'Or']
# Loại bỏ "Or"
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %% [markdown]
# ## Task 3: Reporting

# %% [markdown]
# ### Task 3.1:  What was the best month for sales? How much was earned that month?

# %%
# print(df['Quantity Ordered'].dtypes)
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], downcast='integer')
df['Price Each'] = pd.to_numeric(df['Price Each'], downcast='float')

df['Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#        Order Date                       Purchase Address Month       Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01  700.000000
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01   14.950000
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01   23.980000
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01  149.990005
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01   11.990000

# %%
# Di chuyển cột "Sales"
moving_col = df.pop('Sales')
df.insert(4, 'Sales', moving_col)
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
df.groupby('Month').sum()['Sales']
# Out:
# Month
# 01    1822256.75
# 02    2202022.50
# 03    2807100.25
# 04    3390670.25
# 05    3152606.75
# 06    2577802.25
# 07    2647775.75
# 08    2244467.75
# 09    2097560.00
# 10    3736726.75
# 11    3199603.25
# 12    4613443.50
# Name: Sales, dtype: float32

# %%
sale_values = df.groupby('Month').sum()['Sales']
print(f"{sale_values.max():,.2f}")
# Out:
# 4,613,443.50

# %%
months = range(1,13)
plt.bar(x= months, height =sale_values )
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# ## Task 3.2: What city hase the best sales?

# %%
address_to_city = lambda address:address.split(",")[1]

# %%
df['City'] = df['Purchase Address'].apply(address_to_city)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#             Sales      Order Date                         Purchase Address  \
# ...

# %%
df.groupby('City').sum()['Sales']
# Out:
# City
# Atlanta          2795498.50
# Austin           1819581.75
# Boston           3661642.00
# Dallas           2767975.50
# Los Angeles      5452571.00
# New York City    4664317.50
# Portland         2320490.50
# San Francisco    8262204.00
# Seattle          2747755.50
# Name: Sales, dtype: float32

# %%
sale_values_city = df.groupby('City').sum()['Sales']
print(sale_values_city.max())
# Out:
# 8.262204e+06

# %%
cities = sale_values_city.index
# Hiển thị đúng thứ tự city với sale_values_city

plt.bar(x= cities, height =sale_values_city )
plt.xticks(cities, rotation=45)
plt.xlabel('Cities')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# ### Task 3.3: What time should we display ads to maximize the likelihood of customer's buying product?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month  \
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# C:\Users\MSII\AppData\Local\Temp\ipykernel_14440\3072535395.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
print(df['Order Date'].dtypes)
# Out:
# datetime64[ns]

# %%
df['Hours'] = df['Order Date'].dt.hour

# %%
sale_values_hour = df.groupby('Hours').count()['Sales']
# Count vì cần tối ưu hóa tổng số lượng đơn hàng, k phải doanh thu
# Tức là tìm xem khung thời gian nào có nhiều đơn hàng nhất

# %%
hours = sale_values_hour.index
# Hiển thị đúng thứ tự city với sale_values_city

plt.plot(hours,sale_values_hour )
plt.xticks(hours)
plt.xlabel('Hours')
plt.ylabel('Sales in USD')
plt.grid()
plt.show()

# %% [markdown]
# ### Task 3.4: What products are the most often sold together?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales          Order Date                       Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1   14.950000 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2   23.980000 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3  149.990005 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4   11.990000 2019-01-25 11:59:00          387 10th St, Austin, TX 73301
#
#   Month            City  Hours
# 0    01          Boston     21
# 1    01        Portland     14
# ...

# %%
df_dup = df[df['Order ID'].duplicated(keep=False)]
# Giữ lại những dòng có Order ID bị trùng
df_dup.head()
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each   Sales  \
# 41    141275      USB-C Charging Cable                 1       11.95   11.95
# 42    141275          Wired Headphones                 1       11.99   11.99
# 57    141290  Apple Airpods Headphones                 1      150.00  150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84   11.52
# 133   141365           Vareebadd Phone                 1      400.00  400.00
#
#              Order Date                        Purchase Address Month  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001    01
#
#                City  Hours
# 41           Austin     16
# ...

# %%
# def joinProduct(product):
#     return ','.join(product)
group_product = lambda product: ','.join(product)

# %%
# Nhóm các sản phẩm vào 1 hàng, gom thông tin đơn hàng làm một
df_dup['All_products'] = df_dup.groupby('Order ID')['Product'].transform(group_product)
df_dup.head()
# Out:
# C:\Users\MSII\AppData\Local\Temp\ipykernel_14440\4271458932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup['All_products'] = df_dup.groupby('Order ID')['Product'].transform(group_product)
#     Order ID                   Product  Quantity Ordered  Price Each   Sales  \
# 41    141275      USB-C Charging Cable                 1       11.95   11.95
# 42    141275          Wired Headphones                 1       11.99   11.99
# 57    141290  Apple Airpods Headphones                 1      150.00  150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84   11.52
# 133   141365           Vareebadd Phone                 1      400.00  400.00
#
# ...

# %%
df_dup = df_dup[["Order ID","All_products"]].drop_duplicates()
df_dup
# Out:
#       Order ID                                       All_products
# 41      141275              USB-C Charging Cable,Wired Headphones
# 57      141290     Apple Airpods Headphones,AA Batteries (4-pack)
# 133     141365                   Vareebadd Phone,Wired Headphones
# 153     141384                  Google Phone,USB-C Charging Cable
# 220     141450            Google Phone,Bose SoundSport Headphones
# ...        ...                                                ...
# 11617   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 11619   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 11627   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 11639   259314            Wired Headphones,AAA Batteries (4-pack)
# 11677   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
# Lấy ra giá trị các sản phẩm thường được mua cùng nhau
df_dup["All_products"].value_counts().head(10)
# Out:
# All_products
# iPhone,Lightning Charging Cable                       882
# Google Phone,USB-C Charging Cable                     856
# iPhone,Wired Headphones                               361
# Vareebadd Phone,USB-C Charging Cable                  312
# Google Phone,Wired Headphones                         303
# iPhone,Apple Airpods Headphones                       286
# Google Phone,Bose SoundSport Headphones               161
# Vareebadd Phone,Wired Headphones                      104
# Google Phone,USB-C Charging Cable,Wired Headphones     77
# Vareebadd Phone,Bose SoundSport Headphones             60
# Name: count, dtype: int64

# %% [markdown]
# ### Task 3.5: What product sold the most? Why do you think it the most?

# %%
all_products = df.groupby('Product')['Quantity Ordered'].sum()
all_products
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
prices = df.groupby('Product')['Price Each'].mean()
prices
# Out:
# Product
# 20in Monitor                   109.989998
# 27in 4K Gaming Monitor         389.990021
# 27in FHD Monitor               149.990005
# 34in Ultrawide Monitor         379.990021
# AA Batteries (4-pack)            3.840000
# AAA Batteries (4-pack)           2.990000
# Apple Airpods Headphones       150.000000
# Bose SoundSport Headphones      99.989998
# Flatscreen TV                  300.000000
# Google Phone                   600.000000
# LG Dryer                       600.000000
# LG Washing Machine             600.000000
# Lightning Charging Cable        14.950000
# Macbook Pro Laptop            1700.000000
# ThinkPad Laptop                999.989990
# USB-C Charging Cable            11.950000
# Vareebadd Phone                400.000000
# Wired Headphones                11.990000
# iPhone                         700.000000
# Name: Price Each, dtype: float32

# %%
product_ls = [product for product, quantity in all_products.items()]
plt.bar(x= product_ls, height= all_products)
plt.xticks(product_ls, rotation = 75, size = 8)
plt.xlabel('Products')
plt.ylabel('Quantity')
plt.show()

# %%
# Tại sao lại như vậy?
# Có thể do giá cả, thương hiệu, chất lượng

# %%
x = product_ls
y1 = all_products
y2 = prices

fig, ax1 = plt.subplots(figsize=(7, 4))

ax2 = ax1.twinx()
ax1.bar(x, y1, color='g')
ax2.plot(x, y2, 'b-')

ax1.set_xticklabels(product_ls, rotation = 80, size = 8)
ax1.set_xlabel('Products')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Prices Each', color='b')
ax1.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\MSII\AppData\Local\Temp\ipykernel_14440\3250306903.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(product_ls, rotation = 80, size = 8)

# %%
# Có thể do ảnh hưởng bởi yếu tố thương hiện nên 
# dù giá sản phẩm thấp nhưng số lượng mua cũng không cao (LG)
